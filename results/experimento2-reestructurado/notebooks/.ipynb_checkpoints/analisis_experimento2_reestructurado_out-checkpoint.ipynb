# %% [markdown]
# # An?lisis del Experimento2 Reestructurado
#
# Notebook base para cargar los datos combinados, revisar columnas y preparar el preprocesamiento. Usa la carpeta `data/` local.

# %%
# Importar librer?as necesarias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1. Carga y visualizaci?n de datos
#
# Carga los datos desde `data/` y muestra estad?sticas descriptivas iniciales.

# %%
import os
file_path = os.path.join('..', 'data', 'master_results_combined.csv')
if not os.path.exists(file_path):
    file_path = os.path.join('..', 'data', 'master_results_clean.csv')
if os.path.exists(file_path):
    df = pd.read_csv(file_path)
    print('Columnas detectadas:', df.columns.tolist())
    print('Primeras filas:')
    display(df.head())
    # Validar columnas clave antes de graficar
    columnas_requeridas = ['agent', 'risk_scale', 'reward', 'tripwires']
    for col in columnas_requeridas:
        if col not in df.columns:
            print(f'Advertencia: Falta la columna {col}')
else:
    print(f'No se encontr? el archivo: {file_path}')
# Out:
# Columnas detectadas: ['risk_scale', 'risk_level', 'red_team', 'seed', 'agent', 'episodes', 'steps_per_episode', 'eval_episodes', 'total_timesteps', 'avg_pgf_neto', 'avg_pgf_bruto', 'avg_pgf_costo', 'avg_tripwire', 'avg_reward', 'robustez', 'flexibilidad']
# Primeras filas:
#    risk_scale risk_level  red_team   seed     agent  episodes  \
# 0         0.5    default     False   42.0  ppo_sota    1000.0
# 1         0.5    default     False  123.0  ppo_sota    1000.0
# 2         0.5    default     False  456.0  ppo_sota    1000.0
# 3         1.0    default     False   42.0  ppo_sota    1000.0
# 4         1.0    default     False  123.0  ppo_sota    1000.0
#
#    steps_per_episode  eval_episodes  total_timesteps  avg_pgf_neto  \
# 0               50.0         1000.0          50000.0           0.0
# 1               50.0         1000.0          50000.0           0.0
# 2               50.0         1000.0          50000.0           0.0
# 3               50.0         1000.0          50000.0           0.0
# 4               50.0         1000.0          50000.0           0.0
#
#    avg_pgf_bruto  avg_pgf_costo  avg_tripwire  avg_reward  robustez  \
# 0            0.0            0.0           0.0       645.0       NaN
# 1            0.0            0.0           0.0       645.0       NaN
# 2            0.0            0.0           0.0       645.0       NaN
# 3            0.0            0.0           0.0         0.0       NaN
# 4            0.0            0.0           0.0         0.0       NaN
#
#    flexibilidad
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# Advertencia: Falta la columna reward
# Advertencia: Falta la columna tripwires

# %% [markdown]
# ## 2. Preprocesamiento de datos
#
# Limpieza, transformaci?n y selecci?n de caracter?sticas. Se documentan los pasos y se validan los tipos de datos antes de continuar.
